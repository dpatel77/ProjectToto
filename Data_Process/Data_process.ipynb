# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
#data = pd.read_csv('storm_data_search_results.csv')

csv_file_path = '/Users/foroughmofidi/Downloads/U of Chicago/4. Spring 2024 /Real Time/Final Project/storm_data_search_results.csv'
data = pd.read_csv(csv_file_path)

# %%
data
# Out:
#      EVENT_ID     CZ_NAME_STR    BEGIN_LOCATION BEGIN_DATE  BEGIN_TIME  \
# 0      880671       ADAMS CO.              CARL    3/28/20        1259
# 1      880672       ADAIR CO.              FISK    3/28/20        1300
# 2      880684    MARSHALL CO.            RHODES    3/28/20        1526
# 3      880685  BLACK HAWK CO.          VOORHIES    3/28/20        1639
# 4      880686  BLACK HAWK CO.            ORANGE    3/28/20        1649
# ..        ...             ...               ...        ...         ...
# 312   1129586     DUBUQUE CO.           CASCADE    8/14/23        1225
# 313   1133626      BENTON CO.        BLAIRSTOWN    9/22/23        1642
# 314   1133625      BENTON CO.          GARRISON    9/26/23        1415
# 315   1144995     WEBSTER CO.             CLARE   10/13/23        1312
# 316   1144996      JASPER CO.  NEWTON MUNI ARPT   10/13/23        1509
#
#     EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  \
# ...

# %%
data.describe()
# Out:
#            EVENT_ID   BEGIN_TIME  DEATHS_DIRECT  INJURIES_DIRECT  \
# count  3.170000e+02   317.000000     317.000000       317.000000
# mean   1.011866e+06  1670.930599       0.022082         0.059937
# std    6.243006e+04   310.017907       0.341467         0.412852
# min    8.784190e+05   117.000000       0.000000         0.000000
# 25%    9.811220e+05  1603.000000       0.000000         0.000000
# 50%    9.982840e+05  1720.000000       0.000000         0.000000
# 75%    1.086475e+06  1828.000000       0.000000         0.000000
# max    1.144996e+06  2318.000000       6.000000         5.000000
#
#        DAMAGE_PROPERTY_NUM  DAMAGE_CROPS_NUM     EPISODE_ID     CZ_FIPS  \
# count         3.170000e+02        317.000000     317.000000  317.000000
# mean          7.725804e+05        346.056782  166895.889590   93.921136
# std           6.651945e+06       2448.460877    9584.830837   57.896323
# min           0.000000e+00          0.000000  146196.000000    1.000000
# ...

# %%
# Check NA
data.isnull().sum()
# Out:
# EVENT_ID               0
# CZ_NAME_STR            0
# BEGIN_LOCATION         0
# BEGIN_DATE             0
# BEGIN_TIME             0
# EVENT_TYPE             0
# MAGNITUDE              0
# TOR_F_SCALE            0
# DEATHS_DIRECT          0
# INJURIES_DIRECT        0
# DAMAGE_PROPERTY_NUM    0
# DAMAGE_CROPS_NUM       0
# STATE_ABBR             0
# CZ_TIMEZONE            0
# MAGNITUDE_TYPE         0
# EPISODE_ID             0
# CZ_TYPE                0
# CZ_FIPS                0
# WFO                    0
# INJURIES_INDIRECT      0
# DEATHS_INDIRECT        0
# SOURCE                 0
# FLOOD_CAUSE            0
# TOR_LENGTH             0
# TOR_WIDTH              0
# BEGIN_RANGE            0
# BEGIN_AZIMUTH          0
# END_RANGE              0
# END_AZIMUTH            0
# END_LOCATION           0
# END_DATE               0
# END_TIME               0
# BEGIN_LAT              0
# BEGIN_LON              0
# END_LAT                0
# END_LON                0
# EVENT_NARRATIVE        0
# ...

# %%
# Tornado by start location
data['BEGIN_LOCATION'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(10, 5))
# Out:
# <Axes: xlabel='BEGIN_LOCATION'>

# %%
data['EVENT_TYPE'].value_counts()
# Out:
# EVENT_TYPE
# Tornado    317
# Name: count, dtype: int64

# %%
data['MAGNITUDE'].value_counts()
# Out:
# MAGNITUDE
#     317
# Name: count, dtype: int64

# %%
data['SOURCE'].value_counts()
# Out:
# SOURCE
# NWS Storm Survey             171
# Emergency Manager             41
# Storm Chaser                  39
# Other Federal Agency          26
# Public                        10
# Trained Spotter                9
# Social Media                   8
# Official NWS Observations      5
# Broadcast Media                3
# Law Enforcement                3
# Mesonet                        2
# Name: count, dtype: int64

# %%
data['TOR_LENGTH'].plot(kind='hist', bins=100, title='Tornado Length')
# Out:
# <Axes: title={'center': 'Tornado Length'}, ylabel='Frequency'>

# %%
data['TOR_WIDTH'].plot(kind='hist', bins=100, title='Tornado Width')
# Out:
# <Axes: title={'center': 'Tornado Width'}, ylabel='Frequency'>

# %%
# Select numeric columns
data_num = data.select_dtypes(include=[np.number])
data_num
# Out:
#      EVENT_ID  BEGIN_TIME  DEATHS_DIRECT  INJURIES_DIRECT  \
# 0      880671        1259              0                0
# 1      880672        1300              0                0
# 2      880684        1526              0                0
# 3      880685        1639              0                0
# 4      880686        1649              0                0
# ..        ...         ...            ...              ...
# 312   1129586        1225              0                0
# 313   1133626        1642              0                0
# 314   1133625        1415              0                0
# 315   1144995        1312              0                0
# 316   1144996        1509              0                0
#
#      DAMAGE_PROPERTY_NUM  DAMAGE_CROPS_NUM  EPISODE_ID  CZ_FIPS  \
# 0                  30000                 0      146548        3
# 1                  95000                 0      146548        1
# 2                      0                 0      146548      127
# ...

# %%
# Correlation Matrix

correlation_matrix = data_num.corr()
#print(correlation_matrix)

correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...
